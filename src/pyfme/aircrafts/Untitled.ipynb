# %%
import matplotlib.pyplot as plt
import numpy as np
from pyfme.aircrafts import MeterSpanUAV
# %matplotlib inline

# %%
a = MeterSpanUAV('MeterSpanUAV.pkl')
# Out:
# c:\users\jean\box sync\recherche\aeropython\pyfme\pyfme\src\pyfme\aircrafts\uav.py:89: RuntimeWarning: invalid value encountered in double_scalars
#   self.CL_delta_elev = np.sum(self.data.de*self.data.CLd1)/np.sum(self.data.de**2)
# c:\users\jean\box sync\recherche\aeropython\pyfme\pyfme\src\pyfme\aircrafts\uav.py:93: RuntimeWarning: invalid value encountered in double_scalars
#   self.CM_delta_elev = np.sum(self.data.de*self.data.Cmd1)/np.sum(self.data.de**2)
# c:\users\jean\box sync\recherche\aeropython\pyfme\pyfme\src\pyfme\aircrafts\uav.py:112: RuntimeWarning: invalid value encountered in double_scalars
#   self.Cl_delta_aile = np.sum(self.data.da*self.data.Cld2)/np.sum(self.data.da**2)

# %%
a.data
# Out:
#          CD       CL       CLa  CLb  CLd1      CLd2  CLd3  CLp        CLq  \
# 0   0.10926 -0.59610  4.695136 -0.0   0.0  0.010174   0.0  0.0  15.172236
# 1   0.06861 -0.51117  4.719722  0.0   0.0  0.010249   0.0  0.0  15.139617
# 2   0.04283 -0.42578  4.741895 -0.0   0.0  0.010316   0.0  0.0  15.115658
# 3   0.03158 -0.34000  4.761099 -0.0  -0.0  0.010374   0.0  0.0  15.099114
# 4   0.02748 -0.25391  4.776748  0.0   0.0  0.010425   0.0 -0.0  15.085703
# 5   0.02431 -0.16756  4.788561 -0.0   0.0  0.010467   0.0  0.0  15.071734
# 6   0.02201 -0.08102  4.796507 -0.0   0.0  0.010501  -0.0 -0.0  15.057181
# 7   0.02057  0.00562  4.800561 -0.0   0.0  0.010526   0.0  0.0  15.042063
# 8   0.02001  0.09230  4.800706 -0.0   0.0  0.010543   0.0  0.0  15.026399
# 9   0.02033  0.17895  4.796936 -0.0   0.0  0.010551   0.0 -0.0  15.010212
# 10  0.02152  0.26549  4.789251  0.0   0.0  0.010551   0.0 -0.0  14.993516
# 11  0.02359  0.35186  4.777664 -0.0   0.0  0.010542   0.0  0.0  14.976340
# ...

# %%
plt.plot(a.data.alpha, a.data.CL,'.')
